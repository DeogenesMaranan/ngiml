# %%
import subprocess, sys
from pathlib import Path

REPO_URL = "https://github.com/DeogenesMaranan/ngiml"
REPO_BRANCH = "main"
REPO_DIR = Path("/content/ngiml")

if REPO_DIR.exists():
    subprocess.run(["git", "-C", str(REPO_DIR), "fetch", "origin", REPO_BRANCH], check=True)
    subprocess.run(["git", "-C", str(REPO_DIR), "checkout", REPO_BRANCH], check=True)
    subprocess.run(["git", "-C", str(REPO_DIR), "pull", "origin", REPO_BRANCH], check=True)
else:
    subprocess.run([
        "git",
        "clone",
        "--branch",
        REPO_BRANCH,
        "--single-branch",
        REPO_URL,
        str(REPO_DIR),
    ], check=True)

sys.path.insert(0, str(REPO_DIR))
print(f"Repo ready at {REPO_DIR} on branch {REPO_BRANCH}")

# %%
import os
from pathlib import Path
from huggingface_hub import login, snapshot_download
from google.colab import userdata

HF_TOKEN = userdata.get("HF_TOKEN")
DATASET_REPO = "juhenes/ngiml"
DATASET_REVISION = "main"
DATA_DIR = "/content/data"

if HF_TOKEN:
    login(token=HF_TOKEN)

os.makedirs(DATA_DIR, exist_ok=True)
snapshot_download(
    repo_id=DATASET_REPO,
    repo_type="dataset",
    local_dir=DATA_DIR,
    revision=DATASET_REVISION,
    token=HF_TOKEN,
    resume_download=True,
    allow_patterns=[
        "CASIA1/*", "CASIA2/*", "Columbia/*", "COVERAGE/*",
        "manifest.*", "TampCOCO/*"
    ],
)

root = Path(DATA_DIR)
manifest_files = sorted(
    p for p in root.rglob("manifest.*")
    if p.name in {"manifest.parquet", "manifest.json"}
    and any(parent.name in ["CASIA1", "CASIA2", "Columbia", "COVERAGE", "TampCOCO/*"] for parent in p.parents)
)
tar_count = sum(1 for _ in root.rglob("*.tar")) + sum(1 for _ in root.rglob("*.tar.gz")) + sum(1 for _ in root.rglob("*.tgz"))

print("Dataset ready at", DATA_DIR)
print("Found manifests:", [str(p) for p in manifest_files[:5]])
print("Tar shards count:", tar_count)

# %%
from google.colab import drive
from pathlib import Path

DRIVE_MOUNT = "/content/drive"
OUTPUT_DIR = f"{DRIVE_MOUNT}/MyDrive/ngiml-multiple-datasets"

drive.mount(DRIVE_MOUNT)
Path(OUTPUT_DIR).mkdir(parents=True, exist_ok=True)
print("Checkpoints will be written to", OUTPUT_DIR)

# %%
from pathlib import Path
import json
from collections import Counter

from tools.manifest_utils import find_or_resolve_manifest
from src.data.config import Manifest
from src.data.dataloaders import load_manifest

SELECTED_TRAIN_VAL_DATASETS = ["CASIA2", "TampCOCO"]

data_root = Path(DATA_DIR)
MANIFEST_PATH = find_or_resolve_manifest(data_root)

manifest_obj = load_manifest(MANIFEST_PATH)

train_samples = [
    s for s in manifest_obj.samples
    if s.split == "train" and str(getattr(s, "dataset", "")).upper() in [d.upper() for d in SELECTED_TRAIN_VAL_DATASETS]
]
val_samples = [
    s for s in manifest_obj.samples
    if s.split == "val" and str(getattr(s, "dataset", "")).upper() in [d.upper() for d in SELECTED_TRAIN_VAL_DATASETS]
]

test_samples = [s for s in manifest_obj.samples if s.split == "test"]

filtered_samples = train_samples + val_samples + test_samples
filtered_manifest = Manifest(
    samples=filtered_samples,
    normalization_mode=manifest_obj.normalization_mode
)

FILTERED_MANIFEST_PATH = data_root / 'manifest_filtered.json'
with open(FILTERED_MANIFEST_PATH, 'w', encoding='utf-8') as handle:
    json.dump(filtered_manifest.to_dict(), handle, indent=2)
MANIFEST_PATH = FILTERED_MANIFEST_PATH

train_val_samples = train_samples + val_samples
train_val_split_counts = Counter(s.split for s in train_val_samples)
train_val_dataset_counts = Counter(s.dataset for s in train_val_samples)

print('Using filtered manifest:', MANIFEST_PATH)
print('Train/Val split counts:', dict(train_val_split_counts))
print('Train/Val dataset counts:', dict(train_val_dataset_counts))
print(f'Train samples: {len(train_samples)}, Val samples: {len(val_samples)}, Test samples: {len(test_samples)}')

# %%
import json
import dataclasses

from tools.train_ngiml import TrainConfig
from tools.colab_train_helpers import (
    apply_colab_runtime_settings,
    stage_persistent_cache_to_runtime,
)

PERSISTENT_CACHE_DIR = f"{OUTPUT_DIR}/local_cache"
RUNTIME_CACHE_DIR = "/content/cache"
stage_info = stage_persistent_cache_to_runtime(
    persistent_cache_dir=PERSISTENT_CACHE_DIR,
    runtime_cache_dir=RUNTIME_CACHE_DIR,
    force=False,
)
print("Cache staging:", stage_info)

training_config = TrainConfig(
    manifest=MANIFEST_PATH,
    scheduler_type="cosine",
    output_dir=OUTPUT_DIR,
    batch_size=22,
    epochs=50,
    num_workers=6,
    amp=True,
    pin_memory=True,
    channels_last=True,
    compile_model=True,
    compile_mode="default",
    deterministic=True,
    use_tf32=True,
    precision="bf16",
    gradient_checkpointing=True,
    flash_attention=True,
    xformers=True,
    cuda_expandable_segments=True,
    lr_schedule=True,
    warmup_epochs=3,
    min_lr_scale=0.1,
    grad_clip=1.0,
    grad_accum_steps=1,
    val_every=1,
    checkpoint_every=1,
    resume=None,
    auto_resume=True,
    round_robin_seed=42,
    balance_sampling=False,
    balance_real_fake=True,
    balanced_positive_ratio=0.45,
    balanced_sampler_seed=42,
    balanced_sampler_num_samples=None,
    prefetch_factor=2,
    persistent_workers=False,
    drop_last=True,
    auto_local_cache=True,
    local_cache_dir=RUNTIME_CACHE_DIR,
    reuse_local_cache_manifest=True,
    views_per_sample=4,
    max_short_side=480,
    max_rotation_degrees=8.0,
    noise_std_max=0.010,
    disable_aug=False,
    device="cuda",
    aug_seed=42,
    seed=42,
    early_stopping_patience=4,
    early_stopping_min_delta=5e-4,
    early_stopping_monitor="iou",
    metric_threshold=0.5,
    optimize_threshold=True,
    threshold_metric="f1",
    threshold_start=0.2,
    threshold_end=0.8,
    threshold_step=0.02,
    small_mask_ratio_max=0.01,
    medium_mask_ratio_max=0.05,
    compute_foreground_ratio=True,
    foreground_ratio_max_batches=32,
    short_side_probe_samples=0,
    auto_pos_weight=True,
    pos_weight_min=0.5,
    pos_weight_max=10.0,
    balanced_pos_weight_cap=0.0,
    loss_hybrid_mode="dice_bce",
    dice_weight=1.0,
    bce_weight=1.0,
    focal_gamma=2.0,
    focal_alpha=0.25,
    tversky_weight=0.05,
    tversky_alpha=0.3,
    tversky_beta=0.8,
    lovasz_weight=0.0,
    use_boundary_loss=True,
    boundary_weight=0.05,
    ema_enabled=True,
    ema_decay=0.999,
    hard_mining_enabled=False,
    hard_mining_start_epoch=5,
    hard_mining_weight=0.03,
    hard_mining_gamma=2.0,
    default_aug={
        "enable": True,
        "views_per_sample": 4,
        "enable_flips": True,
        "enable_rotations": True,
        "max_rotation_degrees": 8.0,
        "enable_random_crop": True,
        "crop_scale_range": [0.75, 1.0],
        "object_crop_bias_prob": 0.95,
        "min_fg_pixels_for_object_crop": 4,
        "enable_elastic": False,
        "elastic_prob": 0.0,
        "elastic_alpha": 8.0,
        "elastic_sigma": 5.0,
        "enable_color_jitter": True,
        "color_jitter_factors": [0.9, 1.1],
        "brightness_jitter_factors": [0.9, 1.1],
        "contrast_jitter_factors": [0.9, 1.1],
        "enable_noise": True,
        "noise_std_range": [0.0, 0.010],
    },
    per_dataset_aug={},
    model_config={
        "efficientnet": {
            "pretrained": True,
            "out_indices": [1, 2, 3, 4],
            "enforce_input_size": False,
            "input_size": None,
        },
        "swin": {
            "model_name": "swin_tiny_patch4_window7_224",
            "pretrained": True,
            "out_indices": [0, 1, 2, 3],
            "input_size": 384,
        },
        "residual": {
            "num_kernels": 3,
            "base_channels": 32,
            "num_stages": 4,
        },
        "fusion": {
            "fusion_channels": [64, 128, 192, 256],
            "noise_branch": "residual",
            "noise_skip_stage": None,
            "noise_decay": 1.0,
            "norm": "bn",
            "activation": "relu",
            "fusion_refinement": True,
        },
        "decoder": {
            "decoder_channels": None,
            "out_channels": 1,
            "norm": "in",
            "activation": "relu",
            "per_stage_heads": True,
            "enable_edge_guidance": True,
            "use_dropout": True,
            "dropout_p": 0.2,
        },
        "optimizer": {
            "efficientnet": {
                "lr": 1.0e-05,
                "weight_decay": 1.5e-04
            },
            "swin": {
                "lr": 5.0e-06,
                "weight_decay": 1.0e-04
            },
            "residual": {
                "lr": 2.5e-04,
                "weight_decay": 2.0e-04
            },
            "fusion": {
                "lr": 1.2e-04,
                "weight_decay": 2.0e-04
            },
            "decoder": {
                "lr": 1.8e-04,
                "weight_decay": 2.0e-04
            },
            "betas": [0.9, 0.999],
            "eps": 1.0e-08,
            "freeze_backbone_epochs": 3
        },
        "use_low_level": True,
        "use_context": True,
        "use_residual": True,
        "enable_residual_attention": True,
        "gradient_checkpointing": True,
        "flash_attention": True,
        "xformers": True,
    },
    loss_config={
        "dice_weight": 1.0,
        "bce_weight": 1.0,
        "pos_weight": 1.0,
        "stage_weights": [0.05, 0.1, 0.2, 1.0],
        "smooth": 1e-06,
        "hybrid_mode": "dice_bce",
        "focal_gamma": 2.0,
        "focal_alpha": 0.25,
        "tversky_weight": 0.05,
        "tversky_alpha": 0.3,
        "tversky_beta": 0.8,
        "lovasz_weight": 0.0,
        "use_boundary_loss": True,
        "boundary_weight": 0.05,
        "hard_pixel_mining": False,
    },
    debug_timing=False,
)

print("Configuration successfully loaded.")

BALANCE_SAMPLING = True
TUNE_FOR_LARGE_BATCH = True
training_config = apply_colab_runtime_settings(
    training_config,
    balance_sampling=BALANCE_SAMPLING,
    tune_for_large_batch=TUNE_FOR_LARGE_BATCH,
    local_cache_dir=RUNTIME_CACHE_DIR,
 )

effective_view_multiplier = {
    name: cfg.views_per_sample if cfg.enable else 1
    for name, cfg in training_config.get("per_dataset_aug", {}).items()
}

print("Applied runtime settings:")
summary_keys = [
    "batch_size",
    "num_workers",
    "persistent_workers",
    "pin_memory",
    "auto_local_cache",
    "local_cache_dir",
    "reuse_local_cache_manifest",
    "compile_model",
    "compile_mode",
    "channels_last",
    "use_tf32",
    "balance_sampling",
    "balance_real_fake",
    "balanced_positive_ratio",
    "balanced_pos_weight_cap",
    "resume",
    "auto_resume",
    "threshold_metric",
    "early_stopping_monitor",
    "tversky_weight",
]
print({k: training_config.get(k) for k in summary_keys})
print("Per-dataset views_per_sample:", effective_view_multiplier)

print("Effective training config (post-settings):")
print(json.dumps(
    training_config,
    indent=2,
    default=lambda o: dataclasses.asdict(o) if dataclasses.is_dataclass(o) and not isinstance(o, type) else str(o)
))

# %%
from importlib import reload
from tools import train_ngiml

reload(train_ngiml)

import importlib
try:
    import src.data.dataloaders as dl
    importlib.reload(dl)
except Exception:
    pass

from tools.train_ngiml import AugmentationConfig
if isinstance(training_config.get("default_aug"), type):
    training_config["default_aug"] = AugmentationConfig()
if isinstance(training_config.get("per_dataset_aug"), dict):
    for k, v in training_config["per_dataset_aug"].items():
        if isinstance(v, type):
            training_config["per_dataset_aug"][k] = AugmentationConfig()

cfg = train_ngiml.TrainConfig(**training_config)
train_ngiml.run_training(cfg)

# %%
from collections import defaultdict
from pathlib import Path

import matplotlib.pyplot as plt
import numpy as np
import torch
from tqdm.auto import tqdm

from tools.manifest_utils import find_or_resolve_manifest
from tools.infer_helpers import (
    collate_eval_batch_like_training,
    load_model_from_checkpoint,
    normalize_image_for_inference,
    should_use_high_pass_for_records,
)
from src.data.dataloaders import load_manifest

# --- Setup paths ---
RUN_OUTPUT_DIR = Path(training_config.get("output_dir", OUTPUT_DIR))
CHECKPOINT_DIR = RUN_OUTPUT_DIR / "checkpoints"
if not CHECKPOINT_DIR.exists():
    raise FileNotFoundError(f"Checkpoint directory not found: {CHECKPOINT_DIR}")

TARGET_EPOCH = None
if TARGET_EPOCH is None:
    best_ckpt = CHECKPOINT_DIR / "best_checkpoint.pt"
    if not best_ckpt.exists():
        raise FileNotFoundError("best_checkpoint.pt not found.")
    checkpoint_paths = [best_ckpt]
    CKPT_PATH = best_ckpt
else:
    target_ckpt = CHECKPOINT_DIR / f"checkpoint_epoch_{TARGET_EPOCH:03d}.pt"
    if target_ckpt.exists():
        checkpoint_paths = [target_ckpt]
        CKPT_PATH = target_ckpt
    else:
        checkpoint_paths = sorted(
            CHECKPOINT_DIR.glob(f"checkpoint_epoch_{TARGET_EPOCH}*.pt"),
            key=lambda p: p.stat().st_mtime
        )
        if not checkpoint_paths:
            raise FileNotFoundError(f"No checkpoint found for epoch {TARGET_EPOCH}.")
        CKPT_PATH = checkpoint_paths[-1]

# --- Load manifest ---
MANIFEST_PATH = find_or_resolve_manifest(Path(DATA_DIR))
manifest = load_manifest(MANIFEST_PATH)
INFER_NORMALIZATION = str(getattr(manifest, "normalization_mode", "zero_one")).strip().lower()

# --- Load model ---
model, device, ckpt_info = load_model_from_checkpoint(CKPT_PATH)
VAL_THRESHOLD = float(ckpt_info.get("default_threshold", 0.5))
INFER_MAX_SHORT_SIDE = int(ckpt_info.get("max_short_side", 0) or 0)
VAL_THRESHOLD_SOURCE = str(ckpt_info.get("threshold_source", "unknown"))

threshold_metric_name = str(training_config.get("threshold_metric", "f1")).strip().lower()
threshold_start = float(training_config.get("threshold_start", 0.1))
threshold_end = float(training_config.get("threshold_end", 0.8))
threshold_step = float(training_config.get("threshold_step", 0.02))
if threshold_step <= 0.0:
    raise ValueError(f"threshold_step must be positive, got {threshold_step}")
thresholds = np.round(
    np.arange(threshold_start, threshold_end + 0.5 * threshold_step, threshold_step), 6
)
if thresholds.size == 0:
    raise RuntimeError("Threshold sweep grid is empty.")

# --- Metric helpers ---
def _metrics_from_counts(tp, tn, fp, fn, eps=1e-6):
    iou = (tp + eps) / (tp + fp + fn + eps)
    precision = (tp + eps) / (tp + fp + eps)
    recall = (tp + eps) / (tp + fn + eps)
    f1 = (2.0 * precision * recall) / (precision + recall + eps)
    accuracy = (tp + tn + eps) / (tp + tn + fp + fn + eps)
    return {
        "iou": float(iou),
        "f1": float(f1),
        "precision": float(precision),
        "recall": float(recall),
        "accuracy": float(accuracy),
    }

def _evaluate_threshold(probabilities, targets, threshold):
    tp = tn = fp = fn = 0.0
    for pred_prob, target in zip(probabilities, targets):
        pred = (pred_prob >= threshold).astype(np.float32)
        tp += float((pred * target).sum())
        tn += float(((1.0 - pred) * (1.0 - target)).sum())
        fp += float((pred * (1.0 - target)).sum())
        fn += float(((1.0 - pred) * target).sum())
    return {**_metrics_from_counts(tp, tn, fp, fn), "tp": tp, "tn": tn, "fp": fp, "fn": fn}

def _sweep_thresholds(probabilities, targets):
    rows = []
    best_row = None
    best_score = None
    for threshold in thresholds:
        row = {"threshold": float(threshold), **_evaluate_threshold(probabilities, targets, float(threshold))}
        metric_value = float(row.get(threshold_metric_name, row["f1"]))
        if (
            best_row is None
            or metric_value > best_score + 1e-12
            or (abs(metric_value - best_score) <= 1e-12 and row["f1"] > best_row["f1"] + 1e-12)
            or (
                abs(metric_value - best_score) <= 1e-12
                and abs(row["f1"] - best_row["f1"]) <= 1e-12
                and row["threshold"] < best_row["threshold"]
            )
        ):
            best_row = row
            best_score = metric_value
        rows.append(row)
    return rows, best_row

def _confusion_from_totals(tn, fp, fn, tp):
    return np.array([[tn, fp], [fn, tp]], dtype=np.float64)

# --- Load test samples ---
TEST_SPLIT = "test"
EVAL_BATCH_SIZE = max(1, int(training_config.get("batch_size", 1)))
test_samples = [s for s in manifest.samples if s.split == TEST_SPLIT]
if not test_samples:
    raise RuntimeError(f"No samples found for split={TEST_SPLIT!r} in {MANIFEST_PATH}")

USE_HIGH_PASS_IN_EVAL = should_use_high_pass_for_records(test_samples)

# --- Prepare predictions ---
dataset_probabilities = defaultdict(list)
dataset_targets = defaultdict(list)
all_probabilities = []
all_targets = []

model.eval()
progress = tqdm(total=len(test_samples), desc="Preparing predictions", unit="sample")
for start_idx in range(0, len(test_samples), EVAL_BATCH_SIZE):
    batch_records = test_samples[start_idx:start_idx + EVAL_BATCH_SIZE]
    batch_images, batch_masks, batch_high_pass, _ = collate_eval_batch_like_training(
        batch_records,
        max_short_side=INFER_MAX_SHORT_SIDE,
        use_high_pass=USE_HIGH_PASS_IN_EVAL,
    )

    normalized_batch_images = torch.stack(
        [normalize_image_for_inference(img, INFER_NORMALIZATION) for img in batch_images]
    ).to(device)

    batch_high_pass_device = batch_high_pass.to(device) if batch_high_pass is not None else None

    with torch.no_grad():
        logits = model(
            normalized_batch_images,
            target_size=batch_masks.shape[-2:],
            high_pass=batch_high_pass_device,
        )[-1]
        batch_probs = torch.sigmoid(logits).detach().cpu().numpy()

    batch_targets = (batch_masks[:, 0].cpu().numpy() >= 0.5).astype(np.float32)

    for local_idx, sample in enumerate(batch_records):
        dataset_key = str(sample.dataset)
        dataset_probabilities[dataset_key].append(batch_probs[local_idx, 0])
        dataset_targets[dataset_key].append(batch_targets[local_idx])
        all_probabilities.append(batch_probs[local_idx, 0])
        all_targets.append(batch_targets[local_idx])

    progress.update(len(batch_records))
progress.close()

# --- Calibrate thresholds ---
CALIBRATED_TEST_THRESHOLD_TABLE = {}
CALIBRATED_TEST_THRESHOLDS_BY_DATASET = {}

overall_rows, overall_best = _sweep_thresholds(all_probabilities, all_targets)
CALIBRATED_TEST_THRESHOLD = float(overall_best["threshold"])
CALIBRATED_TEST_THRESHOLD_TABLE["__overall__"] = overall_rows

for dataset_name in sorted(dataset_probabilities):
    rows, best_row = _sweep_thresholds(dataset_probabilities[dataset_name], dataset_targets[dataset_name])
    CALIBRATED_TEST_THRESHOLD_TABLE[dataset_name] = rows
    CALIBRATED_TEST_THRESHOLDS_BY_DATASET[dataset_name] = float(best_row["threshold"])

# --- Define strategies including fixed threshold 0.5 ---
FIXED_THRESHOLD = 0.5
strategies = {
    "val_threshold": {"threshold": VAL_THRESHOLD, "threshold_source": "checkpoint_val_threshold"},
    "swept_threshold": {"threshold": CALIBRATED_TEST_THRESHOLD, "threshold_source": f"swept_test_{threshold_metric_name}"},
    "fixed_threshold_0.5": {"threshold": FIXED_THRESHOLD, "threshold_source": "fixed_0.5"},
}

# --- Evaluate all strategies ---
comparison_rows = []
per_dataset_comparison = {}
for strategy_name, info in strategies.items():
    overall_eval = _evaluate_threshold(all_probabilities, all_targets, float(info["threshold"]))
    per_dataset_eval = {}
    for dataset_name in sorted(dataset_probabilities):
        dataset_threshold = float(info["threshold"])
        dataset_threshold_source = info["threshold_source"]
        if strategy_name == "swept_threshold":
            dataset_threshold = float(CALIBRATED_TEST_THRESHOLDS_BY_DATASET.get(dataset_name, dataset_threshold))
            dataset_threshold_source = f"per_dataset_swept_test_{threshold_metric_name}"
        per_dataset_eval[dataset_name] = _evaluate_threshold(
            dataset_probabilities[dataset_name],
            dataset_targets[dataset_name],
            float(dataset_threshold),
        )
        per_dataset_eval[dataset_name]["threshold"] = float(dataset_threshold)
        per_dataset_eval[dataset_name]["threshold_source"] = str(dataset_threshold_source)

    per_dataset_comparison[strategy_name] = per_dataset_eval
    comparison_rows.append({
        "strategy": strategy_name,
        "threshold": float(info["threshold"]),
        "threshold_source": info["threshold_source"],
        "samples": len(all_probabilities),
        "iou": overall_eval["iou"],
        "f1": overall_eval["f1"],
        "precision": overall_eval["precision"],
        "recall": overall_eval["recall"],
        "accuracy": overall_eval["accuracy"],
        "tp": overall_eval["tp"],
        "tn": overall_eval["tn"],
        "fp": overall_eval["fp"],
        "fn": overall_eval["fn"],
    })

# --- Print overall and per-dataset comparison ---
print("\nOverall strategy comparison:")
for row in comparison_rows:
    print({k: row[k] for k in ["strategy", "threshold", "threshold_source", "iou", "f1", "precision", "recall", "accuracy"]})

print("\nPer-dataset strategy comparison:")
for dataset_name in sorted(dataset_probabilities):
    print(f"Dataset: {dataset_name}")
    for strategy_name in strategies:
        row = per_dataset_comparison[strategy_name][dataset_name]
        print({
            "strategy": strategy_name, # Explicitly use strategy_name from loop
            "threshold": row["threshold"],
            "threshold_source": row["threshold_source"],
            "iou": row["iou"],
            "f1": row["f1"],
            "precision": row["precision"],
            "recall": row["recall"],
            "accuracy": row["accuracy"],
        })

# --- Confusion matrices ---
heatmaps = []
for row in comparison_rows:
    heatmaps.append((f"{row['strategy']}\nthreshold={row['threshold']:.3f}", _confusion_from_totals(row["tn"], row["fp"], row["fn"], row["tp"])))

fig, axes = plt.subplots(1, len(heatmaps), figsize=(6 * len(heatmaps), 4))
if len(heatmaps) == 1:
    axes = [axes]

for ax, (title, confusion_matrix) in zip(axes, heatmaps):
    im = ax.imshow(confusion_matrix, cmap="Blues")
    ax.set_title(f"{title}\nPixel Confusion Matrix")
    ax.set_xticks([0, 1], labels=["Pred Neg", "Pred Pos"])
    ax.set_yticks([0, 1], labels=["True Neg", "True Pos"])
    for row_idx in range(confusion_matrix.shape[0]):
        for col_idx in range(confusion_matrix.shape[1]):
            value = confusion_matrix[row_idx, col_idx]
            ax.text(col_idx, row_idx, f"{value:,.0f}", ha="center", va="center", color="black")
    plt.colorbar(im, ax=ax, fraction=0.046, pad=0.04, label="Pixel count")

plt.tight_layout()
plt.show()

# --- Save globals for later ---
print("\nSaved globals for later cells:")
print({
    "VAL_THRESHOLD": VAL_THRESHOLD,
    "VAL_THRESHOLD_SOURCE": VAL_THRESHOLD_SOURCE,
    "CALIBRATED_TEST_THRESHOLD": CALIBRATED_TEST_THRESHOLD,
    "CALIBRATED_TEST_THRESHOLDS_BY_DATASET": CALIBRATED_TEST_THRESHOLDS_BY_DATASET,
    "FIXED_THRESHOLD": FIXED_THRESHOLD,
})

# %%
# from pathlib import Path
# from collections import defaultdict
# import re
# import matplotlib.pyplot as plt
# import numpy as np
# import pandas as pd
# import torch
# from tqdm.auto import tqdm

# from tools.manifest_utils import find_or_resolve_manifest
# from tools.infer_helpers import (
#     collate_eval_batch_like_training,
#     load_model_from_checkpoint,
#     normalize_image_for_inference,
#     should_use_high_pass_for_records,
#     )
# from src.data.dataloaders import load_manifest

# CHECKPOINT_DIR = Path(training_config.get("output_dir", OUTPUT_DIR)) / "checkpoints"
# if not CHECKPOINT_DIR.exists():
#     raise FileNotFoundError(f"Checkpoint directory not found: {CHECKPOINT_DIR}")

# def _extract_epoch(path: Path) -> int:
#     match = re.search(r"checkpoint_epoch_(\d+)\.pt$", path.name)
#     return int(match.group(1)) if match else -1

# TARGET_EPOCH = None

# if TARGET_EPOCH is None:
#     best_ckpt = CHECKPOINT_DIR / "best_checkpoint.pt"
#     if not best_ckpt.exists():
#         raise FileNotFoundError("best_checkpoint.pt not found.")
#     checkpoint_paths = [best_ckpt]

# else:
#     target_ckpt = CHECKPOINT_DIR / f"checkpoint_epoch_{TARGET_EPOCH:03d}.pt"

#     if target_ckpt.exists():
#         checkpoint_paths = [target_ckpt]
#     else:
#         checkpoint_paths = sorted(
#             CHECKPOINT_DIR.glob(f"checkpoint_epoch_{TARGET_EPOCH}*.pt"),
#             key=lambda p: p.stat().st_mtime
#         )

#         if not checkpoint_paths:
#             raise FileNotFoundError(
#                 f"No checkpoint found for epoch {TARGET_EPOCH}."
#             )

# MANIFEST_PATH = find_or_resolve_manifest(Path(DATA_DIR))
# manifest = load_manifest(MANIFEST_PATH)
# TEST_SPLIT = "test"
# test_samples = [sample for sample in manifest.samples if sample.split == TEST_SPLIT]
# if not test_samples:
#     raise RuntimeError(f"No samples found for split={TEST_SPLIT!r} in manifest {MANIFEST_PATH}")

# samples_by_dataset = defaultdict(list)
# for sample in test_samples:
#     samples_by_dataset[str(sample.dataset)].append(sample)

# normalization_mode = str(getattr(manifest, "normalization_mode", "zero_one")).strip().lower()
# use_high_pass_eval = should_use_high_pass_for_records(test_samples)
# eval_batch_size = max(1, int(training_config.get("batch_size", 1)))

# threshold_start = float(training_config.get("threshold_start", 0.2))
# threshold_end = float(training_config.get("threshold_end", 0.8))
# threshold_step = float(training_config.get("threshold_step", 0.02))
# if threshold_step <= 0.0:
#     raise ValueError(f"threshold_step must be positive, got {threshold_step}")

# thresholds = np.round(np.arange(threshold_start, threshold_end + 0.5 * threshold_step, threshold_step), 6)
# if thresholds.size == 0:
#     raise RuntimeError("Threshold sweep grid is empty. Check threshold_start, threshold_end, and threshold_step.")

# def _metrics_from_counts(tp, tn, fp, fn, eps=1e-6):
#     iou = (tp + eps) / (tp + fp + fn + eps)
#     precision = (tp + eps) / (tp + fp + eps)
#     recall = (tp + eps) / (tp + fn + eps)
#     f1 = (2.0 * precision * recall) / (precision + recall + eps)
#     accuracy = (tp + tn + eps) / (tp + tn + fp + fn + eps)
#     return {
#         "iou": float(iou),
#         "f1": float(f1),
#         "precision": float(precision),
#         "recall": float(recall),
#         "accuracy": float(accuracy),
#     }

# def _evaluate_at_threshold(probabilities, targets, threshold):
#     tp = tn = fp = fn = 0.0
#     for pred_prob, target in zip(probabilities, targets):
#         pred = (pred_prob >= threshold).astype(np.float32)
#         tp += float((pred * target).sum())
#         tn += float(((1.0 - pred) * (1.0 - target)).sum())
#         fp += float((pred * (1.0 - target)).sum())
#         fn += float(((1.0 - pred) * target).sum())
#     return {
#         "tp": tp,
#         "tn": tn,
#         "fp": fp,
#         "fn": fn,
#         **_metrics_from_counts(tp, tn, fp, fn),
#     }

# def _best_swept_threshold(probabilities, targets):
#     best_row = None
#     for threshold in thresholds:
#         row = _evaluate_at_threshold(probabilities, targets, float(threshold))
#         row["threshold"] = float(threshold)
#         if (
#             best_row is None
#             or row["f1"] > best_row["f1"] + 1e-12
#             or (abs(row["f1"] - best_row["f1"]) <= 1e-12 and row["iou"] > best_row["iou"] + 1e-12)
#             or (
#                 abs(row["f1"] - best_row["f1"]) <= 1e-12
#                 and abs(row["iou"] - best_row["iou"]) <= 1e-12
#                 and row["threshold"] < best_row["threshold"]
#             )
#         ):
#             best_row = row
#     return best_row

# def _collect_probs_and_targets(model, device, records, max_short_side):
#     probabilities = []
#     targets = []
#     model.eval()
#     for start_idx in range(0, len(records), eval_batch_size):
#         batch_records = records[start_idx:start_idx + eval_batch_size]
#         batch_images, batch_masks, batch_high_pass, _ = collate_eval_batch_like_training(
#             batch_records,
#             max_short_side=max_short_side,
#             use_high_pass=use_high_pass_eval,
#         )

#         normalized_images = torch.stack(
#             [normalize_image_for_inference(image, normalization_mode=normalization_mode) for image in batch_images],
#             dim=0,
#         ).to(device)

#         batch_high_pass_device = None
#         if batch_high_pass is not None:
#             batch_high_pass_device = batch_high_pass.to(device)

#         with torch.no_grad():
#             logits = model(
#                 normalized_images,
#                 target_size=batch_masks.shape[-2:],
#                 high_pass=batch_high_pass_device,
#             )[-1]
#             batch_probs = torch.sigmoid(logits).detach().cpu().numpy()

#         batch_targets = (batch_masks[:, 0].cpu().numpy() >= 0.5).astype(np.float32)
#         for idx in range(len(batch_records)):
#             probabilities.append(batch_probs[idx, 0])
#             targets.append(batch_targets[idx])

#     return probabilities, targets

# print("Cross-dataset epoch sweep setup:")
# print({
#     "target_epoch": TARGET_EPOCH,
#     "checkpoint_count": len(checkpoint_paths),
#     "datasets": sorted(samples_by_dataset.keys()),
#     "test_samples": len(test_samples),
#     "eval_batch_size": eval_batch_size,
#     "normalization_mode": normalization_mode,
#     "high_pass": use_high_pass_eval,
#     "threshold_range": [float(thresholds[0]), float(thresholds[-1]), float(threshold_step)],
#     "fixed_threshold": 0.5,
# })

# records = []
# progress = tqdm(checkpoint_paths, desc="Epoch sweep", unit="ckpt")
# for checkpoint_path in progress:
#     epoch = _extract_epoch(checkpoint_path)
#     model, device, ckpt_info = load_model_from_checkpoint(checkpoint_path)
#     base_threshold = float(ckpt_info.get("default_threshold", 0.5))
#     fixed_threshold = 0.5
#     max_short_side = int(ckpt_info.get("max_short_side", 0) or 0)

#     all_probs = []
#     all_targets = []

#     for dataset_name in sorted(samples_by_dataset):
#         dataset_records = samples_by_dataset[dataset_name]
#         probs, targets = _collect_probs_and_targets(
#             model=model,
#             device=device,
#             records=dataset_records,
#             max_short_side=max_short_side,
#         )
#         all_probs.extend(probs)
#         all_targets.extend(targets)

#         base_metrics = _evaluate_at_threshold(probs, targets, base_threshold)
#         fixed_metrics = _evaluate_at_threshold(probs, targets, fixed_threshold)
#         swept_metrics = _best_swept_threshold(probs, targets)

#         records.append({
#             "epoch": epoch,
#             "checkpoint": str(checkpoint_path),
#             "dataset": dataset_name,
#             "samples": len(dataset_records),
#             "threshold_mode": "checkpoint_default",
#             "threshold": float(base_threshold),
#             "iou": base_metrics["iou"],
#             "f1": base_metrics["f1"],
#             "precision": base_metrics["precision"],
#             "recall": base_metrics["recall"],
#             "accuracy": base_metrics["accuracy"],
#         })
#         records.append({
#             "epoch": epoch,
#             "checkpoint": str(checkpoint_path),
#             "dataset": dataset_name,
#             "samples": len(dataset_records),
#             "threshold_mode": "fixed_0p5",
#             "threshold": float(fixed_threshold),
#             "iou": fixed_metrics["iou"],
#             "f1": fixed_metrics["f1"],
#             "precision": fixed_metrics["precision"],
#             "recall": fixed_metrics["recall"],
#             "accuracy": fixed_metrics["accuracy"],
#         })
#         records.append({
#             "epoch": epoch,
#             "checkpoint": str(checkpoint_path),
#             "dataset": dataset_name,
#             "samples": len(dataset_records),
#             "threshold_mode": "swept_f1",
#             "threshold": float(swept_metrics["threshold"]),
#             "iou": swept_metrics["iou"],
#             "f1": swept_metrics["f1"],
#             "precision": swept_metrics["precision"],
#             "recall": swept_metrics["recall"],
#             "accuracy": swept_metrics["accuracy"],
#         })

#     overall_base_metrics = _evaluate_at_threshold(all_probs, all_targets, base_threshold)
#     overall_fixed_metrics = _evaluate_at_threshold(all_probs, all_targets, fixed_threshold)
#     overall_swept_metrics = _best_swept_threshold(all_probs, all_targets)

#     records.append({
#         "epoch": epoch,
#         "checkpoint": str(checkpoint_path),
#         "dataset": "__overall__",
#         "samples": len(all_probs),
#         "threshold_mode": "checkpoint_default",
#         "threshold": float(base_threshold),
#         "iou": overall_base_metrics["iou"],
#         "f1": overall_base_metrics["f1"],
#         "precision": overall_base_metrics["precision"],
#         "recall": overall_base_metrics["recall"],
#         "accuracy": overall_base_metrics["accuracy"],
#     })
#     records.append({
#         "epoch": epoch,
#         "checkpoint": str(checkpoint_path),
#         "dataset": "__overall__",
#         "samples": len(all_probs),
#         "threshold_mode": "fixed_0p5",
#         "threshold": float(fixed_threshold),
#         "iou": overall_fixed_metrics["iou"],
#         "f1": overall_fixed_metrics["f1"],
#         "precision": overall_fixed_metrics["precision"],
#         "recall": overall_fixed_metrics["recall"],
#         "accuracy": overall_fixed_metrics["accuracy"],
#     })
#     records.append({
#         "epoch": epoch,
#         "checkpoint": str(checkpoint_path),
#         "dataset": "__overall__",
#         "samples": len(all_probs),
#         "threshold_mode": "swept_f1",
#         "threshold": float(overall_swept_metrics["threshold"]),
#         "iou": overall_swept_metrics["iou"],
#         "f1": overall_swept_metrics["f1"],
#         "precision": overall_swept_metrics["precision"],
#         "recall": overall_swept_metrics["recall"],
#         "accuracy": overall_swept_metrics["accuracy"],
#     })

#     del model
#     if torch.cuda.is_available():
#         torch.cuda.empty_cache()

# results_df = pd.DataFrame(records).sort_values(
#     ["epoch", "dataset", "threshold_mode"],
#     ascending=[True, True, True],
# ).reset_index(drop=True)

# RESULTS_DIR = CHECKPOINT_DIR
# cross_eval_csv = RESULTS_DIR / "cross_dataset_epoch_sweep.csv"
# results_df.to_csv(cross_eval_csv, index=False)

# print("Saved:", cross_eval_csv)
# print("Top overall checkpoints by threshold mode (F1):")
# for mode in ("checkpoint_default", "fixed_0p5", "swept_f1"):
#     print(f"\nMode: {mode}")
#     display(
#         results_df[
#             (results_df["dataset"] == "__overall__")
#             & (results_df["threshold_mode"] == mode)
#         ]
#         .sort_values(["f1", "iou"], ascending=False)
#         .head(10)
#     )

# print("Latest epoch per-dataset summary by threshold mode:")
# latest_epoch = int(results_df["epoch"].max())
# for mode in ("checkpoint_default", "fixed_0p5", "swept_f1"):
#     print(f"\nMode: {mode}")
#     display(
#         results_df[
#             (results_df["epoch"] == latest_epoch)
#             & (results_df["threshold_mode"] == mode)
#         ]
#         .sort_values(["dataset", "f1"], ascending=[True, False])
#     )

# swept_df = results_df[results_df["threshold_mode"] == "swept_f1"].copy()
# if not swept_df.empty:
#     per_dataset_swept = swept_df[swept_df["dataset"] != "__overall__"].copy()
#     overall_swept = swept_df[swept_df["dataset"] == "__overall__"].copy()

#     fig, axes = plt.subplots(1, 2, figsize=(16, 5))

#     for dataset_name, group in per_dataset_swept.groupby("dataset"):
#         group = group.sort_values("epoch")
#         axes[0].plot(group["epoch"], group["f1"], marker="o", linewidth=2, label=dataset_name)
#         axes[1].plot(group["epoch"], group["threshold"], marker="o", linewidth=2, label=dataset_name)

#     if not overall_swept.empty:
#         overall_swept = overall_swept.sort_values("epoch")
#         axes[0].plot(
#             overall_swept["epoch"],
#             overall_swept["f1"],
#             marker="o",
#             linewidth=3,
#             linestyle="--",
#             color="black",
#             label="__overall__",
#         )
#         axes[1].plot(
#             overall_swept["epoch"],
#             overall_swept["threshold"],
#             marker="o",
#             linewidth=3,
#             linestyle="--",
#             color="black",
#             label="__overall__",
#         )

#     axes[0].set_title("Swept Threshold F1 Trend by Dataset")
#     axes[0].set_xlabel("Epoch")
#     axes[0].set_ylabel("F1")
#     axes[0].grid(True, alpha=0.3)
#     axes[0].legend(loc="best")

#     axes[1].set_title("Selected Swept Threshold Trend by Dataset")
#     axes[1].set_xlabel("Epoch")
#     axes[1].set_ylabel("Threshold")
#     axes[1].grid(True, alpha=0.3)
#     axes[1].legend(loc="best")

#     plt.tight_layout()
#     plt.show()
# else:
#     print("No swept_f1 rows found; skipping trend plots.")

# %%
from collections import defaultdict
from pathlib import Path

import matplotlib.pyplot as plt
import numpy as np
import torch
import matplotlib.cm as cm

from tools.manifest_utils import find_or_resolve_manifest
from tools.infer_helpers import (
    collate_eval_batch_like_training,
    load_model_from_checkpoint,
    normalize_image_for_inference,
    should_use_high_pass_for_records,
)
from src.data.dataloaders import load_manifest

# -----------------------------
# Paths and checkpoints
# -----------------------------
RUN_OUTPUT_DIR = Path(training_config.get("output_dir", OUTPUT_DIR))
CHECKPOINT_DIR = RUN_OUTPUT_DIR / "checkpoints"
if not CHECKPOINT_DIR.exists():
    raise FileNotFoundError(f"Checkpoint directory not found: {CHECKPOINT_DIR}")

TARGET_EPOCH = None

if TARGET_EPOCH is None:
    best_ckpt = CHECKPOINT_DIR / "best_checkpoint.pt"
    if not best_ckpt.exists():
        raise FileNotFoundError("best_checkpoint.pt not found.")
    checkpoint_paths = [best_ckpt]
    CKPT_PATH = best_ckpt

else:
    target_ckpt = CHECKPOINT_DIR / f"checkpoint_epoch_{TARGET_EPOCH:03d}.pt"

    if target_ckpt.exists():
        checkpoint_paths = [target_ckpt]
        CKPT_PATH = target_ckpt
    else:
        checkpoint_paths = sorted(
            CHECKPOINT_DIR.glob(f"checkpoint_epoch_{TARGET_EPOCH}*.pt"),
            key=lambda p: p.stat().st_mtime
        )

        if not checkpoint_paths:
            raise FileNotFoundError(
                f"No checkpoint found for epoch {TARGET_EPOCH}."
            )
        CKPT_PATH = checkpoint_paths[-1]

# -----------------------------
# Load manifest
# -----------------------------
MANIFEST_PATH = find_or_resolve_manifest(Path(DATA_DIR))
manifest = load_manifest(MANIFEST_PATH)
INFER_NORMALIZATION = str(getattr(manifest, "normalization_mode", "zero_one")).strip().lower()

# -----------------------------
# Load model
# -----------------------------
model, device, ckpt_info = load_model_from_checkpoint(CKPT_PATH)
INFER_MAX_SHORT_SIDE = int(ckpt_info.get("max_short_side", 0) or 0)

# -----------------------------
# Prepare test samples
# -----------------------------
test_samples = [sample for sample in manifest.samples if sample.split == "test"]
fake_test_samples = [sample for sample in test_samples if int(getattr(sample, "label", 0)) == 1]
if not fake_test_samples:
    fake_test_samples = [sample for sample in test_samples if sample.mask_path is not None]

samples_by_dataset = defaultdict(list)
for sample in fake_test_samples:
    samples_by_dataset[str(sample.dataset)].append(sample)

if not samples_by_dataset:
    raise RuntimeError("No fake test samples found in manifest.")

USE_HIGH_PASS_IN_EVAL = should_use_high_pass_for_records(fake_test_samples)

# -----------------------------
# Utility functions
# -----------------------------
def _to_hwc_rgb(image_chw):
    image = image_chw.detach().cpu().numpy()
    if image.shape[0] == 1:
        image = np.repeat(image, 3, axis=0)
    return np.transpose(image, (1, 2, 0))

def _overlay_threshold(image_hwc, heatmap, threshold=0.5, color=(1.0, 0.0, 0.0), alpha=0.5):
    """
    Overlay a binary mask derived from thresholded heatmap over an image.
    """
    overlay = image_hwc.copy()
    mask = (heatmap >= threshold)
    color_arr = np.array(color).reshape(1, 1, 3)
    overlay[mask] = (1 - alpha) * overlay[mask] + alpha * color_arr
    return np.clip(overlay, 0.0, 1.0)

# -----------------------------
# Run inference & visualization
# -----------------------------
print("Using checkpoint:", CKPT_PATH)
print("Target epoch:", TARGET_EPOCH)
print("Using manifest:", MANIFEST_PATH)
print("Fake-only test samples by dataset:", {k: len(v) for k, v in sorted(samples_by_dataset.items())})

model.eval()
for dataset_name in sorted(samples_by_dataset):
    selected = samples_by_dataset[dataset_name][:5]
    if not selected:
        continue

    fig, axes = plt.subplots(len(selected), 4, figsize=(16, 4 * len(selected)))
    if len(selected) == 1:
        axes = np.expand_dims(axes, axis=0)

    for row_idx, sample in enumerate(selected):
        batch_images, batch_masks, batch_high_pass, _ = collate_eval_batch_like_training(
            [sample],
            max_short_side=INFER_MAX_SHORT_SIDE,
            use_high_pass=USE_HIGH_PASS_IN_EVAL,
        )

        image_for_model = normalize_image_for_inference(
            batch_images[0],
            normalization_mode=INFER_NORMALIZATION,
        ).unsqueeze(0).to(device)

        high_pass_for_model = None
        if batch_high_pass is not None:
            high_pass_for_model = batch_high_pass.to(device)

        with torch.no_grad():
            logits = model(
                image_for_model,
                target_size=batch_masks.shape[-2:],
                high_pass=high_pass_for_model,
            )[-1]
            prob = torch.sigmoid(logits)[0, 0].detach().cpu().numpy()

        image = _to_hwc_rgb(batch_images[0])
        gt = (batch_masks[0, 0].detach().cpu().numpy() >= 0.5).astype(np.float32)

        # Overlay using threshold
        overlay = _overlay_threshold(image, prob, threshold=0.5, color=(1.0, 0.0, 0.0), alpha=0.5)

        axes[row_idx, 0].imshow(np.clip(image, 0.0, 1.0))
        axes[row_idx, 0].set_title("image")
        axes[row_idx, 0].axis("off")

        axes[row_idx, 1].imshow(gt, cmap="gray", vmin=0, vmax=1)
        axes[row_idx, 1].set_title("gt")
        axes[row_idx, 1].axis("off")

        axes[row_idx, 2].imshow(prob, cmap="magma", vmin=0, vmax=1)
        axes[row_idx, 2].set_title("pred (magma)")
        axes[row_idx, 2].axis("off")

        axes[row_idx, 3].imshow(overlay)
        axes[row_idx, 3].set_title("overlay@0.5")
        axes[row_idx, 3].axis("off")

    fig.suptitle(f"Dataset: {dataset_name} | First {len(selected)} fake test examples", fontsize=14)
    plt.tight_layout()
    plt.show()

# %%
from pathlib import Path
import json, glob, torch, pandas as pd

CHECKPOINTS_DIR = Path(f"{OUTPUT_DIR}/checkpoints/")

def load_json_logs(checkpoints_dir: Path):
    logs = []
    main = checkpoints_dir / "checkpoint_metrics.json"
    candidates = [main] + sorted(checkpoints_dir.glob("checkpoint_metrics.json.corrupt.*"))
    for p in candidates:
        if not p.exists():
            continue
        try:
            with open(p, "r", encoding="utf-8") as fh:
                data = json.load(fh)
            if isinstance(data, dict):
                logs.extend([data])
            elif isinstance(data, list):
                logs.extend(data)
            print(f"Loaded {len(data) if isinstance(data,(list,dict)) else 'N/A'} entries from {p.name}")
            if p == main:
                break
        except Exception as e:
            print(f"Failed to read {p.name}: {e}")
    return logs

def scan_checkpoints(checkpoints_dir: Path):
    records = []
    pattern = str(checkpoints_dir / "checkpoint_epoch_*.pt")
    files = sorted(glob.glob(pattern), key=lambda p: int(Path(p).stem.split("_")[-1]) if Path(p).stem.split("_")[-1].isdigit() else -1)
    for p in files:
        try:
            ck = torch.load(p, map_location="cpu")
        except Exception as e:
            print(f"Skipping unreadable checkpoint {p}: {e}")
            continue
        rec = {
            "checkpoint_path": str(p),
            "epoch": int(ck.get("epoch", -1)) if isinstance(ck.get("epoch", None), (int,float,str)) else None,
            "global_step": int(ck.get("global_step", 0)) if ck.get("global_step", None) is not None else None,
        }
        for k in ("train_loss","val_loss","iou","f1","precision","recall","accuracy"):
            if k in ck:
                rec[k] = ck[k]
        for maybe in ("metrics","eval_metrics","val_metrics"):
            if maybe in ck and isinstance(ck[maybe], dict):
                for k,v in ck[maybe].items():
                    rec.setdefault(k, v)
        records.append(rec)
    return records

json_logs = load_json_logs(CHECKPOINTS_DIR)
if json_logs:
    df = pd.DataFrame(json_logs)
else:
    print("No JSON metrics log found -> scanning checkpoints for embedded info")
    scanned = scan_checkpoints(CHECKPOINTS_DIR)
    df = pd.DataFrame(scanned)

if "epoch" in df.columns:
    df["epoch"] = pd.to_numeric(df["epoch"], errors="coerce").fillna(-1).astype(int)
df = df.sort_values(by=["epoch","global_step"], ascending=[True, True]).reset_index(drop=True)

print(f"Collected {len(df)} records. Preview:")
display(df.head(50))
out_csv = CHECKPOINTS_DIR / "checkpoint_metrics_collected.csv"
df.to_csv(out_csv, index=False)
print("Saved CSV to", out_csv)

# %%
from pathlib import Path
import torch, pandas as pd

CHECKPOINTS_DIR = Path(f"{OUTPUT_DIR}/checkpoints/")
best_path = CHECKPOINTS_DIR / "best_checkpoint.pt"

if not best_path.exists():
    raise FileNotFoundError("best_checkpoint.pt not found.")

ck = torch.load(best_path, map_location="cpu")

rec = {
    "checkpoint_path": str(best_path),
    "epoch": int(ck.get("epoch", -1)) if isinstance(ck.get("epoch", None), (int, float, str)) else None,
    "global_step": int(ck.get("global_step", 0)) if ck.get("global_step", None) is not None else None,
}

for k in ("train_loss","val_loss","iou","f1","precision","recall","accuracy"):
    if k in ck:
        rec[k] = ck[k]

for maybe in ("metrics","eval_metrics","val_metrics"):
    if maybe in ck and isinstance(ck[maybe], dict):
        for k, v in ck[maybe].items():
            rec.setdefault(k, v)

df_best = pd.DataFrame([rec])

print("Best checkpoint info:")
display(df_best)

if rec["epoch"] in (-1, None):
    print("Epoch not found directly. Available keys:")
    print(list(ck.keys()))

# %%
import subprocess
import sys
from pathlib import Path

import torch

from tools.infer_helpers import load_model_from_checkpoint

try:
    from thop import clever_format, profile
except Exception:
    subprocess.check_call([sys.executable, "-m", "pip", "install", "-q", "thop"])
    from thop import clever_format, profile

RUN_OUTPUT_DIR = Path(training_config.get("output_dir", OUTPUT_DIR))
CHECKPOINT_DIR = RUN_OUTPUT_DIR / "checkpoints"
if not CHECKPOINT_DIR.exists():
    raise FileNotFoundError(f"Checkpoint directory not found: {CHECKPOINT_DIR}")

TARGET_EPOCH = None

if TARGET_EPOCH is None:
    best_ckpt = CHECKPOINT_DIR / "best_checkpoint.pt"
    if not best_ckpt.exists():
        raise FileNotFoundError("best_checkpoint.pt not found.")
    checkpoint_paths = [best_ckpt]
    CKPT_PATH = best_ckpt

else:
    target_ckpt = CHECKPOINT_DIR / f"checkpoint_epoch_{TARGET_EPOCH:03d}.pt"

    if target_ckpt.exists():
        checkpoint_paths = [target_ckpt]
        CKPT_PATH = target_ckpt
    else:
        checkpoint_paths = sorted(
            CHECKPOINT_DIR.glob(f"checkpoint_epoch_{TARGET_EPOCH}*.pt"),
            key=lambda p: p.stat().st_mtime
        )

        if not checkpoint_paths:
            raise FileNotFoundError(
                f"No checkpoint found for epoch {TARGET_EPOCH}."
            )
        CKPT_PATH = checkpoint_paths[-1]

model, _, ckpt_info = load_model_from_checkpoint(CKPT_PATH)
model = model.cpu().eval()

input_size = int(384)
input_size = max(32, input_size)

class _NgimlForProfiling(torch.nn.Module):
    def __init__(self, base_model):
        super().__init__()
        self.base_model = base_model

    def forward(self, x):
        out = self.base_model(x, target_size=x.shape[-2:], high_pass=None)
        if isinstance(out, (list, tuple)):
            return out[-1]
        return out

wrapper = _NgimlForProfiling(model).eval()
dummy = torch.randn(1, 3, input_size, input_size, dtype=torch.float32)

with torch.no_grad():
    macs, params = profile(wrapper, inputs=(dummy,), verbose=False)

total_params = sum(p.numel() for p in model.parameters())
trainable_params = sum(p.numel() for p in model.parameters() if p.requires_grad)
flops = 2.0 * macs

macs_hr, params_hr = clever_format([macs, params], "%.3f")
flops_hr = clever_format([flops], "%.3f")

print("Checkpoint:", CKPT_PATH)
print("Target epoch:", TARGET_EPOCH)
print("Input shape:", tuple(dummy.shape))
print("Trainable params:", f"{trainable_params:,}")
print("Total params:", f"{total_params:,}")
print("THOP params:", params_hr)
print("MACs:", macs_hr)
print("Approx FLOPs (2 * MACs):", flops_hr)
